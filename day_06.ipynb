# %% [markdown]
# <a href="https://colab.research.google.com/github/Anupam00111/Anupam00111/blob/main/day_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#reading the dataset
iris = pd.read_csv("/content/drive/MyDrive/ csv/iris.csv")
print(iris)
#dataset visualization
sns.FacetGrid(iris,hue='class').map(plt.scatter,'sepallength','sepalwidth').add_legend()
#preparing the trainning and testing dataset
X=iris.iloc[:,1:5]
y=iris['class']
sc = StandardScaler()
#scalling the dataset
X = sc.fit_transform(X)
#splitting the dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# Out:
#      Index  sepallength  sepalwidth  petallength  petalwidth           class
# 0        0          5.1         3.5          1.4         0.2     Iris-setosa
# 1        1          4.9         3.0          1.4         0.2     Iris-setosa
# 2        2          4.7         3.2          1.3         0.2     Iris-setosa
# 3        3          4.6         3.1          1.5         0.2     Iris-setosa
# 4        4          5.0         3.6          1.4         0.2     Iris-setosa
# ..     ...          ...         ...          ...         ...             ...
# 145    145          6.7         3.0          5.2         2.3  Iris-virginica
# 146    146          6.3         2.5          5.0         1.9  Iris-virginica
# 147    147          6.5         3.0          5.2         2.0  Iris-virginica
# 148    148          6.2         3.4          5.4         2.3  Iris-virginica
# 149    149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 6 columns]
